# %%
## Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
## Matplotlib a data visualization and graphical plotting libray 
## five types of plot is barplot,scatterplot, histogram,sub plot etc

# %%
## Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
##plot a scatter plot.

## scatterplot is the dot represents of two diff value
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("This is my plot")
plt.scatter(x,y)
plt.show()

# %%
##Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
## subplot is to plot multiple plots on a single figure
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(1,2,1)
plt.plot(x,y)
x1 = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
x2 = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,1,1)
plt.plot(x,y)
x3= np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
## Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
## it shows the relation b/w numeric and categoric variable
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.xlabel("company")
plt.ylabel("profit")
plt.show()

# %%
## Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
## box plot is a graph for summarising a set of data it also shows the outliers
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data=[box1,box2]
plt.boxplot(data)
plt.show()
